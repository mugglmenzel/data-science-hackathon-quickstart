# %% [markdown]
# # Get Started with Jupyter on Google Cloud
# In the following you find various helpful code examples which show you how to access data or start ML routines on Google Cloud resources like CPUs, GPUs, or TPUs.
#
# Our first task is to import all necessary libraries used in the examples below.

# %%
import pandas as pd

# %% [markdown]
# ## Access Data on Google Cloud Storage

# %% [markdown]
# Cloud Storage is a storage service in the Google Cloud. It can store virtually infinite amounts of data. Typically, Cloud Storage is used to store files with unstructured data, such as images, text files, and semi-structured file formats, such as CSV, Avro, Parquet, and TFRecords.
#
# We start by creating a Cloud Storage client in Python. The client allows us to interact with the Cloud Storage service. With the client we can download and upload files.

# %%
from google.cloud import storage
client = storage.Client()
print("Client created using default project: {}".format(client.project))
project_id = client.project
# Out:
# Client created using default project: sandbox-michael-menzel

# %% [markdown]
# To explicitly specify a project when constructing the client, set the `project` parameter:

# %%
# client = storage.Client(project='your-project-id')

# %% [markdown]
# First, we work with a bucket which is a root folder in Cloud Storage. Buckets can contain many files and have (practically) no size limit. Here is how we access our bucket for the hackathon:

# %%
bucket_name = "public-sample-data-data-science-hackathon"
bucket = client.get_bucket(bucket_name)

print("Bucket name: {}".format(bucket.name))
print("Bucket location: {}".format(bucket.location))
print("Bucket storage class: {}".format(bucket.storage_class))
# Out:
# Bucket name: public-sample-data-data-science-hackathon
# Bucket location: EU
# Bucket storage class: STANDARD

# %% [markdown]
# Let's list all files in the bucket:

# %%
blobs = bucket.list_blobs()

print("Blobs in {}:".format(bucket.name))
for item in blobs:
    print("\t" + item.name)
# Out:
# Blobs in public-sample-data-data-science-hackathon:
# 	sample.csv

# %% [markdown]
# We can also use the gsutil command line tool for a list:

# %%
# !gsutil ls gs://{bucket_name}
# Out:
# gs://public-sample-data-data-science-hackathon/sample.csv

# %% [markdown]
# Now we can get details about one of the files, download it, and load into a dataframe:

# %%
blob_name = "sample.csv"
blob = bucket.get_blob(blob_name)

print("Name: {}".format(blob.id))
print("Size: {} bytes".format(blob.size))
print("Content type: {}".format(blob.content_type))
print("Public URL: {}".format(blob.public_url))

output_file_name = "/tmp/sample.csv"
blob.download_to_filename(output_file_name)

print("Downloaded blob {} to {}.".format(blob.name, output_file_name))
# Out:
# Name: public-sample-data-data-science-hackathon/sample.csv/1571217850249200
# Size: 7157 bytes
# Content type: application/octet-stream
# Public URL: https://storage.googleapis.com/public-sample-data-data-science-hackathon/sample.csv
# Downloaded blob sample.csv to /tmp/sample.csv.

# %% [markdown]
# Again, the same can be achieved using the gsutil command line tool:

# %%
# !gsutil cp gs://{bucket_name}/{blob_name} /tmp/{blob_name}
# Out:
# Copying gs://public-sample-data-data-science-hackathon/sample.csv...
# / [1 files][  7.0 KiB/  7.0 KiB]
# Operation completed over 1 objects/7.0 KiB.

# %% [markdown]
# With the file stored locally, we can load it into a Pandas dataframe:

# %%
df = pd.read_csv(output_file_name, header=None)
df.describe()
# Out:
#                    0                                                  1   \
# count              13                                                 13
# unique             13                                                 13
# top     Getränke Bier  https://www.edeka24.de/Lebensmittel/Nuesse-Fru...
# freq                1                                                  1
#
#                                              2   \
# count                                        13
# unique                                       13
# top     Meica Mini Wini Singles extra zart 260g
# freq                                          1
#
#                                                        3                 4   \
# count                                                   9                13
# unique                                                  9                13
# top     Bei unserer leckeren REWE Beste Wahl frischen ...  product_id_store
# freq                                                    1                 1
#
#                                       5                     6     7     8   \
# count                                 13                    13    12    13
# unique                                13                    13    10     5
# top     816ff5f8088f0b049d61e22a88d93d79  65g (100 g = 1,68 )  0,50  gram
# freq                                   1                     1     2     8
#
#           9   ...     14     15  16       17       18     19    20   21  22  \
# count     13  ...     13      1  13       13       13     13    13   13  13
# unique    11  ...      2      1   2       13        7     13     8    3   3
# top     3.99  ...  FALSE  score   1  product  Nahrung  02132  0111  011  01
# freq       2  ...     12      1  12        1        4      1     4   10  10
#
#                                   23
# count                              1
# unique                             1
# top     Controversial_Classification
# freq                               1
#
# [4 rows x 24 columns]

# %% [markdown]
# And we should have a look into the dataframe:

# %%
df.head()
# Out:
#                                                   0   \
# 0                                           category
# 1  Nahrungsmittel Nudeln, Reis & Getreide Reis Ba...
# 2                    Nahrungsmittel Backzutaten Mehl
# 3       Nahrungsmittel Brot & Backwaren Aufbackwaren
# 4                                Lebensmittel Nudeln
#
#                                                   1   \
# 0                                                url
# 1  https://shop.rewe.de/p/davert-echter-basmati-r...
# 2  https://shop.rewe.de/p/goldpuder-weizenmehl-ty...
# 3  https://shop.rewe.de/p/rewe-beste-wahl-baguett...
# 4  https://www.edeka24.de/Lebensmittel/Nudeln/Bar...
#
#                                  2   \
# 0                      product_name
# 1   Davert Echter Basmati Reis 500g
# 2  Goldpuder Weizenmehl Typ 405 5kg
# 3     REWE Beste Wahl Baguette 360g
# 4            Barilla Nudeln Fusilli
#
#                                                   3   \
# 0                                product_description
# 1  In Nord Indien, am Fuße des Himalayas befindet...
# 2                                                NaN
# 3  Im Backofen in wenigen Minuten schnell zuberei...
# 4                      Teigwaren aus Hartweizengrieß
#
#                                            4   \
# 0                            product_id_store
# 1   p/davert-echter-basmati-reis-500g/8752591
# 2  p/goldpuder-weizenmehl-typ-405-5kg/4477286
# 3     p/rewe-beste-wahl-baguette-360g/1079106
# 4                 TY4y6t3wbijnjwhGWBzBEd-1142
#
#                                  5                     6    7         8   \
# 0                        product_id                volume  qty      unit
# 1  fa3ff18774b0e1304931e13b31296f65  500g (1 kg = 7,98 )  500      gram
# 2  ee64a255097af44bb99d432271796682   5kg (1 kg = 0,80 )    5  kilogram
# 3  711dfea4c27e434c2384f09b4aeb25c3  360g (1 kg = 2,75 )  360      gram
# 4  bd3abb2f23de5861632b954d9a99d6b3         Inhalt: 500 g  500      gram
#
#       9   ...         14     15           16  \
# 0  price  ...  reduction  score  match_level
# 1   3.99  ...      FALSE    NaN            1
# 2   3.99  ...      FALSE    NaN            1
# 3   0.99  ...      FALSE    NaN            1
# 4   1.69  ...      FALSE    NaN            1
#
#                                                   17            18  \
# 0                                            product  agg_category
# 1  https://shop.rewe.de/p/davert-echter-basmati-r...       Nahrung
# 2  https://shop.rewe.de/p/goldpuder-weizenmehl-ty...       Nahrung
# 3  https://shop.rewe.de/p/rewe-beste-wahl-baguett...       Nahrung
# 4  https://www.edeka24.de/Lebensmittel/Nudeln/Bar...       Lebensm
#
#               19             20             21             22  \
# 0  Coicop5_Final  Coicop4_Final  Coicop3_Final  Coicop2_Final
# 1          01111           0111            011             01
# 2          01112           0111            011             01
# 3          01113           0111            011             01
# 4          01116           0111            011             01
#
#                              23
# 0  Controversial_Classification
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Let's use Panda's built-in support for Google Cloud Storage:

# %%
df = pd.read_csv('gs://public-sample-data-data-science-hackathon/sample.csv', dtype=str)
df.describe()
# Out:
#                                 category  \
# count                                 12
# unique                                12
# top     Lebensmittel Nüsse/Früchte/Samen
# freq                                   1
#
#                                                       url  \
# count                                                  12
# unique                                                 12
# top     https://shop.rewe.de/p/davert-echter-basmati-r...
# freq                                                    1
#
#                                    product_name  \
# count                                        12
# unique                                       12
# top     Meica Mini Wini Singles extra zart 260g
# freq                                          1
#
#                                       product_description  \
# count                                                   8
# unique                                                  8
# top     Bei unserer leckeren REWE Beste Wahl frischen ...
# freq                                                    1
#
#                         product_id_store                        product_id  \
# count                                 12                                12
# unique                                12                                12
# top     4gn9fe52eff7475bc8270473c539b3fc  88f34a92b134c6f9b08cb0b86778fe09
# freq                                   1                                 1
#
#                                     volume   qty  unit price  ... reduction  \
# count                                   12    11    12    12  ...        12
# unique                                  12     9     4    10  ...         1
# top     1 Stück ca. 200 g (1 kg = 36,90 )  0,50  gram  3.99  ...     FALSE
# freq                                     1     2     8     2  ...        12
#
#        score match_level                                            product  \
# count      0          12                                                 12
# unique     0           1                                                 12
# top      NaN           1  https://shop.rewe.de/p/davert-echter-basmati-r...
# freq     NaN          12                                                  1
#
#        agg_category Coicop5_Final Coicop4_Final Coicop3_Final Coicop2_Final  \
# count            12            12            12            12            12
# unique            6            12             7             2             2
# top         Nahrung         02132          0111           011            01
# freq              4             1             4            10            10
#
#        Controversial_Classification
# count                             0
# unique                            0
# top                             NaN
# freq                            NaN
#
# [4 rows x 24 columns]

# %% [markdown]
# And .head() should return the same lines as with our manual download:

# %%
df.head()
# Out:
#                                             category  \
# 0  Nahrungsmittel Nudeln, Reis & Getreide Reis Ba...
# 1                    Nahrungsmittel Backzutaten Mehl
# 2       Nahrungsmittel Brot & Backwaren Aufbackwaren
# 3                                Lebensmittel Nudeln
# 4                     Frische & Kühlung Fleisch Lamm
#
#                                                  url  \
# 0  https://shop.rewe.de/p/davert-echter-basmati-r...
# 1  https://shop.rewe.de/p/goldpuder-weizenmehl-ty...
# 2  https://shop.rewe.de/p/rewe-beste-wahl-baguett...
# 3  https://www.edeka24.de/Lebensmittel/Nudeln/Bar...
# 4  https://shop.rewe.de/p/wilhelm-brandenburg-lam...
#
#                                         product_name  \
# 0                    Davert Echter Basmati Reis 500g
# 1                   Goldpuder Weizenmehl Typ 405 5kg
# 2                      REWE Beste Wahl Baguette 360g
# 3                             Barilla Nudeln Fusilli
# 4  Wilhelm Brandenburg Lamm Rückensteak ohne Knoc...
#
#                                  product_description  \
# 0  In Nord Indien, am Fuße des Himalayas befindet...
# 1                                                NaN
# 2  Im Backofen in wenigen Minuten schnell zuberei...
# 3                      Teigwaren aus Hartweizengrieß
# 4  VOR DEM VERZEHR GUT DURCHGAREN. NICHT ZUM ROHV...
#
#                                     product_id_store  \
# 0          p/davert-echter-basmati-reis-500g/8752591
# 1         p/goldpuder-weizenmehl-typ-405-5kg/4477286
# 2            p/rewe-beste-wahl-baguette-360g/1079106
# 3                        TY4y6t3wbijnjwhGWBzBEd-1142
# 4  p/wilhelm-brandenburg-lamm-rueckensteak-ohne-k...
#
#                          product_id                              volume  qty  \
# 0  fa3ff18774b0e1304931e13b31296f65                500g (1 kg = 7,98 )  500
# 1  ee64a255097af44bb99d432271796682                 5kg (1 kg = 0,80 )    5
# 2  711dfea4c27e434c2384f09b4aeb25c3                360g (1 kg = 2,75 )  360
# 3  bd3abb2f23de5861632b954d9a99d6b3                       Inhalt: 500 g  500
# 4  88f34a92b134c6f9b08cb0b86778fe09  1 Stück ca. 200 g (1 kg = 36,90 )    1
#
#        unit price  ... reduction score match_level  \
# 0      gram  3.99  ...     FALSE   NaN           1
# 1  kilogram  3.99  ...     FALSE   NaN           1
# 2      gram  0.99  ...     FALSE   NaN           1
# 3      gram  1.69  ...     FALSE   NaN           1
# 4      gram  7.38  ...     FALSE   NaN           1
#
#                                              product agg_category  \
# 0  https://shop.rewe.de/p/davert-echter-basmati-r...      Nahrung
# 1  https://shop.rewe.de/p/goldpuder-weizenmehl-ty...      Nahrung
# 2  https://shop.rewe.de/p/rewe-beste-wahl-baguett...      Nahrung
# 3  https://www.edeka24.de/Lebensmittel/Nudeln/Bar...      Lebensm
# 4  https://shop.rewe.de/p/wilhelm-brandenburg-lam...      Frische
#
#   Coicop5_Final Coicop4_Final Coicop3_Final Coicop2_Final  \
# 0         01111          0111           011            01
# 1         01112          0111           011            01
# 2         01113          0111           011            01
# 3         01116          0111           011            01
# 4         01123          0112           011            01
#
#   Controversial_Classification
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **Learn more about interacting with Cloud Storage in the following tutorials:**
# - [Cloud Storage client library](../tutorials/storage/Cloud%20Storage%20client%20library.ipynb)
# - [Storage command-line tool](../tutorials/storage/Storage%20command-line%20tool.ipynb)

# %% [markdown]
# ## Access Tables & Views on Google BigQuery

# %%
from google.cloud import bigquery
client = bigquery.Client(location="EU")
print("Client creating using default project: {}".format(client.project))
# Out:
# Client creating using default project: sandbox-michael-menzel

# %% [markdown]
# To explicitly specify a project when constructing the client, set the `project` parameter:

# %%
# client = bigquery.Client(location="US", project="your-project-id")

# %%
query = """
    SELECT `timestamp`, transaction_id, block_id
    FROM `bigquery-public-data.bitcoin_blockchain.transactions`
    LIMIT 60
"""
query_job = client.query(query, location="US")
df = query_job.to_dataframe()
df.describe()
# Out:
#           timestamp
# count  6.000000e+01
# mean   1.401283e+12
# std    1.275228e+11
# min    1.232107e+12
# 25%    1.271254e+12
# 50%    1.514928e+12
# 75%    1.515270e+12
# max    1.515801e+12

# %%
df.head()
# Out:
#        timestamp                                     transaction_id  \
# 0  1241693386000  b78dd4052c5c19ed15bff7f7cbc072cb87601680165412...
# 1  1261947871000  bfcb4467092290da3bee702d5ffedfe1933c36a18b0e77...
# 2  1262072718000  a069017c031239357a6d325c7a10e6f4ed7cb722b1cb38...
# 3  1261474382000  9b9d3a70b70df897e2383fe16a09286502222f7ca06653...
# 4  1277392209000  3fe2d7fa73e776f591e075783bc24cbd3e2fff8d444c72...
#
#                                             block_id
# 0  000000006b6810ea2b71871065c31f0939c61bc73ca19e...
# 1  000000003d0aa75d182618516bf64536d94119d23ef412...
# 2  00000000b574d15c470a479874f19ea232b8b26e3ab742...
# 3  000000006224e9ce1dbe8a9b593d8f0485a19983b479bd...
# 4  0000000001ad7196de0396085a3fa95f2322722aa8b805...

# %% [markdown]
# You can also execute a query using the BigQuery magic expression in a cell:

# %%
# %%bigquery --verbose df
# SELECT `timestamp`, transaction_id, block_id
# FROM `bigquery-public-data.bitcoin_blockchain.transactions`
# LIMIT 60
# Out:
# Executing query with job ID: 518518a2-e1ac-4bd7-847b-b6e1acebd7ae
# Query executing: 0.45s
# Query complete after 0.67s

# %%
df.head()
# Out:
#        timestamp                                     transaction_id  \
# 0  1260877681000  c0ce69e1272486661aa56673ca5c988bc898ddf5269016...
# 1  1261677656000  2160f284d8f818cb76225ad07eaca026d6d8f860f8aa02...
# 2  1266112798000  790b1a2a3e246718889eb05bb747b8817ee85dad882228...
# 3  1241222355000  366e80396c61babc4c001daadab0e68a7c47db24be0e2e...
# 4  1271617286000  268ee4e02e4ba11185ff78f85800766dd90c0bd71aa4cd...
#
#                                             block_id
# 0  0000000084e1341d1202440622599aabaee14e017109d9...
# 1  00000000c17522535540533052ce12a6db0c9123c026e7...
# 2  0000000009eb1ee6db7c8ea6e3c9f1ccf37a4c99192881...
# 3  00000000ba16045c3dae8a6b1abee685a1c0db2d56195c...
# 4  0000000013eedbaf2f3a8e5c8a9df17fb1219992251774...

# %% [markdown]
# **Learn more about interacting with BigQuery in the following tutorials:**
# - [BigQuery basics](../tutorials/bigquery/BigQuery%20basics.ipynb)
# - [BigQuery command-line tool](../tutorials/bigquery/BigQuery%20command-line%20tool.ipynb)
# - [BigQuery query magic](../tutorials/bigquery/BigQuery%20query%20magic.ipynb)

# %% [markdown]
# ## PAIR Visualizations

# %%
# !pip3 install -q facets-overview

# Introduce facets
from IPython.core.display import display, HTML
from facets_overview.generic_feature_statistics_generator import GenericFeatureStatisticsGenerator
import base64
import uuid

def facets_overview(df):
    gfsg = GenericFeatureStatisticsGenerator()
    proto = gfsg.ProtoFromDataFrames([{'name': 'df', 'table': df}])
    protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")

    HTML_TEMPLATE = """
            <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
            <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
            <facets-overview id="facets-overview-{uuid}"></facets-overview>
            <script>
              document.querySelector("#facets-overview-{uuid}").protoInput = "{protostr}";
            </script>"""

    html = HTML_TEMPLATE.format(protostr=protostr, uuid=uuid.uuid4())
    display(HTML(html))

def facets_dive(df): 
    HTML_TEMPLATE = """
            <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
            <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
            <facets-dive id="facets-dive-{uuid}" height="500"></facets-dive>
            <script>
              document.querySelector("#facets-dive-{uuid}").data = {jsonstr};
            </script>"""

    jsonstr = df.to_json(orient='records')
    html = HTML_TEMPLATE.format(jsonstr=jsonstr, uuid=uuid.uuid4())
    display(HTML(html))

# %%
facets_overview(df)
# Out:
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-overview id="facets-overview-0c3fe0b1-5262-49c6-9e87-6ab9b96e01d2"></facets-overview>
#             <script>
#               document.querySelector("#facets-overview-0c3fe0b1-5262-49c6-9e87-6ab9b96e01d2").protoInput = "...";
#             </script>

# %%
facets_dive(df)
# Out:
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-dive id="facets-dive-cb09833c-af5b-4e2a-a79b-365ae080a99e" height="500"></facets-dive>
#             <script>
#               document.querySelector("#facets-dive-cb09833c-af5b-4e2a-a79b-365ae080a99e").data = [{"timestamp":1260877681000,"transaction_id":"c0ce69e1272486661aa56673ca5c988bc898ddf526901673ff15bdb6e7bcc7ff","block_id":"0000000084e1341d1202440622599aabaee14e017109d910c44bb03e92d824df"},{"timestamp":1261677656000,"transaction_id":"2160f284d8f818cb76225ad07eaca026d6d8f860f8aa024454b8917bdfd86bbb","block_id":"00000000c17522535540533052ce12a6db0c9123c026e7d465a05d399dc52270"},{"timestamp":1266112798000,"transaction_id":"790b1a2a3e246718889eb05bb747b8817ee85dad882228846d8b087786962264","block_id":"0000000009eb1ee6db7c8ea6e3c9f1ccf37a4c99192881fa5d7c0cf85abc3a6d"},{"timestamp":1241222355000,"transaction_id":"366e80396c61babc4c001daadab0e68a7c47db24be0e2e1a95904accafbc2cc6","block_id":"00000000ba16045c3dae8a6b1abee685a1c0db2d56195c5cd90a49b05c97b51c"},{"timestamp":1271617286000,"transaction_id":"268ee4e02e4ba11185ff78f85800766dd90c0bd71aa4cd8d6702cb852ed0e8b9","block_id":"0000000013eedbaf2f3a8e5c8a9df17fb12199922517745dd3ffe38e7666bfb4"},{"timestamp":1274539960000,"transaction_id":"da9574640c4e02e50ea11a0392bcf1a624e6d3b857e9fd6a0700e9b203bb776c","block_id":"000000000cb88168f4b1d17de2cdff9ba44add6225b48e225764a8d4d006d337"},{"timestamp":1270044324000,"transaction_id":"881e8d2bafb5034f5614eac03b0c304c12c9e352234c3cb99290dc72aada07ff","block_id":"00000000242af006fa03b39dfff6d0b0ecc2fcf82e893b26eea642da6a089651"},{"timestamp":1273272168000,"transaction_id":"2e72a40e113e41b9fc84ea82ec8d242ff7b86baf2a1fafac6264cf2d7ac72311","block_id":"000000000bab03317b5113e3c14276f92845da4b57e991b91ec76ec0d2caa6ae"},{"timestamp":1264790811000,"transaction_id":"d293ecec8b95b6a74cbb72a418f98fb348841ddf9a1a05a20de0850b942abf35","block_id":"00000000adc9a23158ffdbd75eed3b25ab6994d8344de94c35e1279f3b982657"},{"timestamp":1257474675000,"transaction_id":"235c76d372f694eff85ec7ce1907a092c5219287033a8567e10684afdb4844cf","block_id":"00000000b7d14bfd9d54c32c7dc81e637b6c598636dbbf111596ae6aef8d2c2a"},{"timestamp":1263804009000,"transaction_id":"8ade904c1f958d75dbb977c7bc7da35e5dbe793da31788d6f06bc62ae13a648c","block_id":"0000000088909081816be8736680015872cf0d8347f691d0b23bb91a543e5ef1"},{"timestamp":1265547750000,"transaction_id":"065a823fc805e8dad260ed256080aa31a0a054c9b6bfa4eb48dfcdc195b28cfc","block_id":"000000002a9ca3f287cb1b4c3be88b77b9e807403daf48ee8094dffdc4df76e0"},{"timestamp":1266608140000,"transaction_id":"e478b4aea2cfd23d44318d16f9c81d548f21451d30c1515386157577d3b1a732","block_id":"00000000383996284333b81859082000e8d90a55124f467e383950ffa5dee667"},{"timestamp":1264139807000,"transaction_id":"d3e3242ac9ad9e02ff15ff06292bdeec1d2c186d356bc081b2fa28ad62e9f919","block_id":"00000000a57809e07fd7c531ddd5d0a213bc02faa83f520ec5ca79f915bbe935"},{"timestamp":1266413067000,"transaction_id":"bb42f0cd1e31b725cfca515463123c26a5a9bf7831edc82de126446b672d0a86","block_id":"000000002881c5aa2206ac64ed889dbd844bd1432156f4cca2f937881c028d44"},{"timestamp":1256101701000,"transaction_id":"91a179f4de80e6b1391ab8578c880ea986f8daa37b8a4f26d9a2863a287a98fb","block_id":"00000000eae1962afd5159d52b0fe7ac3723984561c386c0abd2ae45ed54be79"},{"timestamp":1262160965000,"transaction_id":"e4c5bf1fa33215a6a7ed748b18f6cc17fbb1e5aae77e92dc94b660d90a76520a","block_id":"000000005fa4a17c0db57cb367765ea0ba75f5b566f314099f569e0dd7268c01"},{"timestamp":1260941942000,"transaction_id":"7e44da9b1cf75483dff2bebf32be3a323e5c3e565e2332c49b97b3b865c81ed4","block_id":"00000000304eea8b7371fc211aed2d5ae9ca3b84460c9c195ec9ae8742a92691"},{"timestamp":1271613446000,"transaction_id":"c958096dfdad6828f684097ab83482bbe1feab14b976f4f1410b33b58c903cd0","block_id":"000000001a13a2e138c99ffd7dadb1c92439833d96f85bed92f5d83729e48706"},{"timestamp":1264616023000,"transaction_id":"240697998973130cde14eaf3ca108246c9fcbda9ce105ff3e4c52ee0009dc124","block_id":"0000000045c0a8f00a5c1e8d2c953a79114b2414f1c7f95b41178e52da0935fa"},{"timestamp":1271810432000,"transaction_id":"15976918700367807b5474477c93bb142ed14b3a5c735d3e4a0e15af4 ...

# %% [markdown]
# ## Cloud AI APIs and Cloud AutoML

# %% [markdown]
# Some useful resources to get started with our Cloud APIs for NLP and [AutoML](https://cloud.google.com/automl/) for NLP:
# * [Cloud NLP Intro](https://cloud.google.com/natural-language/)
# * [Cloud Natural Language API Docs](https://cloud.google.com/natural-language/docs/)
# * [Cloud AutoML Get Started Guides](https://cloud.google.com/natural-language/overview/docs/get-started)
# * [Cloud AutoML NLP in the Console](https://console.cloud.google.com/natural-language)
#
# There is also [Cloud AutoML Tables](https://cloud.google.com/automl-tables/) to build ML models on tabular data (e.g. from BigQuery):
# * [Cloud AutoML Tables Intro](https://cloud.google.com/automl-tables/)
# * [Cloud AutoML Tables Docs](https://cloud.google.com/automl-tables/docs/)
# * [Cloud AutoML Tables in the Console](https://console.cloud.google.com/automl-tables)

# %% [markdown]
# ## Data Transformation with Apache Beam (and Cloud Dataflow)

# %%
# !pip3 install -q apache-beam[gcp]

# %%
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions, StandardOptions, DebugOptions, GoogleCloudOptions, WorkerOptions

pipeline_options = PipelineOptions.from_dictionary({
    'runner': 'DirectRunner',
# Run it massively parallel on Dataflow with
#   'runner': 'DataflowRunner'
    'job_name': 'notebook',
    'streaming': True
})

def collect(i):
    output.append(i)
    return True

output = []

p = beam.Pipeline(options=pipeline_options)

pipeline = (
    p 
    | 'generate' >> beam.Create(range(1000))
    | 'square' >> beam.Map(lambda x: x**2)
    | "print" >> beam.Map(collect)
)

result = p.run()
result.wait_until_finish()

output[:10]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
import apache_beam.io as io
import apache_beam.io.fileio as fileio

target_bucket = '[YOUR_TARGET_BUCKET]'

input_file = f"gs://{bucket_name}/sample.csv"
output_file = f"gs://{target_bucket}/converted.csv"
output_file_local = './converted.csv'

options = PipelineOptions()
options.view_as(StandardOptions).runner = 'DataflowRunner'
options.view_as(StandardOptions).streaming = False

google_cloud_options = options.view_as(GoogleCloudOptions)
google_cloud_options.project = project_id
google_cloud_options.job_name = 'prepare-sample-csv'
google_cloud_options.region = 'europe-west1'
google_cloud_options.staging_location = f"gs://{target_bucket}/staging"
google_cloud_options.temp_location = f"gs://{target_bucket}/temp"

# %%
from io import StringIO
from functools import reduce
import csv
import uuid

def file_cacher(row):
    filename = "/tmp/%s.tmp" % uuid.uuid4()
    print("Caching %s" % filename)
    with open(filename, "a") as f:
        f.write(row)
    f.close()
    return filename

def read_file(file):
    rows = file.read_utf8().split('\n')
    rows[0] = rows[0].replace('.', '_')
    return rows

def csv_reader(rows):
    return list(
        pd.read_csv(StringIO(rows), 
                    delimiter=',',
                    verbose=True)
          .replace({'-': None})
          .replace({pd.np.nan: None})
          .to_dict('records'))   

def csv_writer(rows):
    csv_str = StringIO("")
    writer = csv.DictWriter(csv_str, fieldnames=rows[0].keys())
    writer.writeheader()
    for row in rows:
        writer.writerow(row)
    return csv_str.getvalue()

def csv_trimmer(row):
    stripped_row = ";".join(map(str.strip, row.split(';')))
    return stripped_row

def concatinator(rows):
    return "\n".join(rows)

def id_filter(row):
    return row['product_id'] is not None and row['product_id'] != ''

def data_printer(data, verbose=True):
    if verbose:
        print("Data: %s" % data)
    return data

# %%
p = beam.Pipeline(options=options)

cleaned = (p 
           | 'List CSV files' >> fileio.MatchFiles(input_file)
           | 'Download CSV files' >> fileio.ReadMatches()
           | 'Read CSV files into rows' >> beam.ParDo(read_file)
           | 'Trim values in row' >> beam.Map(csv_trimmer)
           | 'Concatenate rows' >> beam.CombineGlobally(concatinator)
           | 'Parse as CSV format' >> beam.FlatMap(csv_reader)
           | 'Remove rows with empty ID' >> beam.Filter(id_filter)
           | 'Print data' >> beam.Map(data_printer, True))

to_csv = (cleaned   
           | 'Collect CSV dicts into list' >> beam.transforms.combiners.ToList()
           | 'Convert rows to CSV' >> beam.Map(csv_writer))

to_csv | 'Write to Cloud Storage' >> io.WriteToText(output_file)
to_csv | 'Write to local file' >> io.WriteToText(output_file_local)

result = p.run()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: MatchFiles is experimental.
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: ReadMatches is experimental.
#   # This is added back by InteractiveShellApp.init_path()
# WARNING:root:Discarding unparseable args: ['-f', '/home/jupyter/.local/share/jupyter/runtime/kernel-3cefc0ac-f449-4cdd-bce4-6c52d023f775.json']
# WARNING:root:Discarding unparseable args: ['-f', '/home/jupyter/.local/share/jupyter/runtime/kernel-3cefc0ac-f449-4cdd-bce4-6c52d023f775.json']

# %% [markdown]
# ## Train Models with Google Cloud AI Platform Training

# %% [markdown]
# We want to enable the ML and Container Registry APIs in our project.

# %%
# !gcloud services enable ml.googleapis.com
# !gcloud services enable containerregistry.googleapis.com

# %% [markdown]
# Then, we need to create a bucket for the staging and training results. Replace with your favorite name (needs to be globally unique!):

# %%
# !gsutil mb gs://[YOUR_GCS_BUCKET]

# %% [markdown]
# Ready to start our Training Job! Fill in in your bucket name where you find brackets. You can modify the model_dir parameter to change where the training output is stored.

# %%
gcloud ml-engine jobs submit training $JOB_NAME \
    --staging-bucket [YOUR_GCS_BUCKET] \
    --runtime-version 1.8 \
    --scale-tier BASIC_TPU \
    --module-name resnet.resnet_main \
    --package-path resnet/ \
    --region us-central1 \
    -- \
    --data_dir=gs://cloud-tpu-test-datasets/fake_imagenet \
    --model_dir=gs://[YOUR_GCS_BUCKET]/training_result/ \
    --resnet_depth=50 \
    --train_steps=1024

# %% [markdown]
# Learn more about AI Platform Training & Serving with ML Engine:
# - [Training & Serving on ML Engine with SciKit Learn](../tutorials/cloud-ml-engine/Training%20and%20prediction%20with%20scikit-learn.ipynb)
# - [Github Repo full of Training & Prediction Examples](https://github.com/GoogleCloudPlatform/cloudml-samples)
